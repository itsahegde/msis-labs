# %%
#Single LinkedList operations

# %%
#Linkedlist implementation in python. Using classes.

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

# %%
node1 = Node(5)
node2 = Node(6)
node3 = Node(13)
node4 = Node(9)
node5 = Node(11)

# %%
node1.next = node2
node2.next = node3
node3.next = node4
node4.next = node5
node5.next = None

# %%
head = node1

# %%
curr = head

# %% [markdown]
# #Traversal of singly linked list

# %%
while curr:
    print(curr.data)
    curr = curr.next
# Out:
# 5
# 6
# 13
# 9
# 11

# %%
#Insertion at beginning

# %%
node6 = Node(19)
node6.data
# Out:
# 19

# %%
node6.next = node1
head = node6

# %%
curr = head

# %%
while curr:
    print(curr.data)
    curr = curr.next
# Out:
# 19
# 5
# 6
# 13
# 9
# 11

# %%
#insertion at end

# %%
last = None
curr = head
while curr.next:
    curr = curr.next
last = curr

# %%
last.data
# Out:
# 11

# %%
node7 = Node(13)
last.next = node7
node7.next = None

# %%
curr = head
while curr:
    print(curr.data)
    curr = curr.next
# Out:
# 12
# 5
# 6
# 8
# 9
# 11
# 13

# %%
#insertion in the middle
i = 3
curr = head
for i in range(i-1):
    print(curr.data)
    curr=curr.next

node8 = Node(14)
node8.next = curr.next.next
curr.next = node8
# Out:
# 12
# 5

# %%
curr = head
while curr:
    print(curr.data)
    curr=curr.next
# Out:
# 12
# 5
# 6
# 14
# 9
# 11
# 13

# %%
#removal from last

# %%
curr = head
while curr.next.next:
    curr = curr.next
curr.data
curr.next = None

# %%
curr = head
while curr:
    print(curr.data)
    curr = curr.next
# Out:
# 12
# 5
# 6
# 14
# 9
# 11

# %%
#removal from first

# %%
head = head.next.next
curr = head
while curr:
    print(curr.data)
    curr = curr.next
# Out:
# 6
# 14
# 9
# 11

# %%
#removal from middle
wanted = 9
curr = head
while curr.next.data!=wanted:
    print(curr.data)
    curr = curr.next
curr.data
# Out:
# 6
# 14

# %%
curr.next = curr.next.next

# %%
curr = head
while curr:
    print(curr.data)
    curr = curr.next
# Out:
# 6
# 14
# 11

# %%
node9 = Node(21)
node10 = Node(22)
node11 = Node(9)

node9.next = node10
node10.next = node11
node11.next = None

# %%
curr = head
while curr.next:
    curr = curr.next
curr.data
# Out:
# 11

# %%
curr.next = node9

# %%
curr = head
while curr:
    print(curr.data)
    curr = curr.next
# Out:
# 6
# 14
# 11
# 21
# 22
# 9
