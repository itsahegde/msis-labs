# %% [markdown]
# Lab Assignment - 03 Sept 2026
# Use the students marks vs study hours dataset. COnvert dataset to csv and then proceed with whatever learnt until now

# %% [markdown]
# Use Residual and Scatter plots
