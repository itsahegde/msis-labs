# %% [markdown]
# Use students final marks datasets. First apply multiple linear regression without ridge, then apply ridge with manual alpha, and then apply ridgecv

# %%
data = {
    'hours': [2, 4, 6, 8, 10],
    'classes': [3, 4, 5, 6, 8],
    'score': [65, 70, 75, 85, 95]
}

# %%
# use ordinary least squares model. predict for a student who studied 7 hours and 5 classes
